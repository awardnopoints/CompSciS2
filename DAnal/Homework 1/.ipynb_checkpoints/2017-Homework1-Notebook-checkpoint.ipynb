# %% [markdown]
# # Homework1
#
# Please upload to Moodle a .zip archive containing your Jupyter Notebook with solutions and all data required to reproduce your solutions.
#
# Please also prepare a requirements.txt file which lists all the packages that you have used for your homework, one package per line. This will allow us to install all required packages in one go, by using "pip install -r requirements.txt".
#
# Please name your .zip archive using your full name and student id as follows - *Firstname_Lastname_12345678_COMP47350_Homework1.zip*.
#
# For your Notebook, please split the code and explanations into many little cells so it is easy to see and read the results of each step of your solution. Please remember to name your variables and methods with self-explanatory names. Please remember to write comments and where needed, justifications, for the decisions you make and code you write. Feel free to revisit *tips_to_keep_your_ipython_notebook_readable_and_easy_to_debug.html* provided on Moodle.
#
# Your code and analysis is like a story that awaits to be read, make it a nice story please.
#
# The accepted file formats for the homework are:
#     - .ipynb
#     - .zip
#     - .pdf
#     - .csv
#
# Please keep the whole code in a single notebook. Usage of external tools/files is discouraged for portability reasons. Files in any other format but mentioned above can be used but will be ignored and not considered for the submission (including .doc, .rar, .7z, .pages, .xlsx, .tex etc.).
# Any image format is allowed to be used as far as the images appear embedded in your report (.ipynb or .pdf or .html).
#
# **Deadline: Sunday, 25 February, 2017, midnight.**

# %% [markdown]
# ## Exercises
#
# This homework focuses on data understanding and preparation for a particular problem and dataset.
# The problem and data come from a mobile phone company concerned with reducing customer churn. Customer churn happens when a customer switches mobile operator. The company wants to use the data collected about their customers to build a data analytics solution for customer churn prediction.
#
# Each student will work with a different subset of the data. The CSV file is named using the format: **CustomerChurn-[your-student-number].csv**, e.g., **CustomerChurn-12345678.csv** is the data file for a student with number 12345678. You need to work with the CSV file corresponding to your student number. The CSV file contains data describing each customer and whether the customer churned (last column in the CSV). There are 3 parts for this homework. Each part has an indicative maximum percentage given in brackets, e.g., part (1) has a maximum of 50% shown as [50].
#
#
#
# (1). [50] Prepare a data quality report for the CSV file. Below you have a set of guideline steps to help you in this process.
#     - Check how many rows and columns your CSV has.
#     - Print the first and the last 5 rows.
#     - Convert the features to their appropriate data types (e.g., decide which features are more appropriate as
#     continuos and which ones as categorical types).
#     - Drop duplicate rows and columns, if any.
#     - Drop constant columns, if any.
#     - Save your updated/cleaned data frame to a new csv file.
#
#     For the updated CSV and data frame (after column/row removal):
#     - Prepare a table with descriptive statistics for all the continuous features.
#     - Prepare a table with descriptive statistics for all the categorical features.
#     - Plot histograms for all the continuous features.
#     - Plot box plots for all the continuous features.
#     - Plot bar plots for all the categorical features.
#     - Discuss your initial findings.
#     - Save the initial discussion of your findings into a single data quality report PDF
#     file.
#
# (2). [30] Prepare a data quality plan for the cleaned CSV file (look for the type of problems we discussed in the lecture).
#     - Mark down all the features where there are potential problems or data quality issues.
#     - Propose solutions to deal with the problems identified. Explain why did you choose one solution over
#     potentially many other.
#     - Apply your solutions to obtain a new CSV file where the identified data quality issues were addressed.
#     - Save the new CSV file with a self explanatory name. Save the data quality plan to a single PDF file (as a
#     table or a structured text).
#
# (3). [20] Exploring relationships between feature pairs:
#     - Choose a subset of features you find promising and plot pairwise feature interactions (e.g.,
#     continuous-continuous feature plot or continuous-categorical plots or correlation plots). Explain your choices.
#     - Discuss your findings from the plots above. Do you find any features or feature combinations that are
#     indicative of the target outcome (i.e., churn)? Explain in plain words (a short paragraph) the story of your
#     findings so far.

# %% [markdown]
# ## Data Quality Report

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns
from matplotlib.backends.backend_pdf import PdfPages
# %matplotlib inline

# %%
pd.get_option("display.max_columns")
# Out:
# 40

# %%
df = pd.read_csv('CustomerChurn-17205709.csv')

# %%
#Check how many rows and columns your CSV has

df.shape
# Out:
# (1000, 33)

# %%
#Print the first and the last 5 rows.

df.head(5)
# Out:
#    customer   age  occupation  regionType marriageStatus  children   income  \
# 0   1074015     0                                unknown     false        0
# 1   1067357    70                suburban             no     false        7
# 2   1014203    52     retired    suburban            yes      true        8
# 3   1061952     0                 unknown        unknown     false        0
# 4   1059557    26                                     no     false        3
#
#    numHandsets  handsetAge smartPhone  currentHandsetPrice  creditRating  \
# 0            1         403       true                 0.00             G
# 1            2         279       true                29.99             E
# 2            2           5      false                29.99             G
# 3            1         478       true                 0.00             D
# 4            1         430       true                 0.00             B
#
#   homeOwner  creditCard  avgBill  avgMins  avgrecurringCharge  \
# 0      true       false    42.79  1097.75               44.99
# 1     false        true    62.22   605.50               41.28
# 2     false        true    35.75   558.50               44.99
# 3      true       false    55.37   362.50               39.99
# 4     false           t    33.85   246.25               30.00
#
#    avgOverBundleMins  avgRoamCalls  callMinutesChangePct  billAmountChangePct  \
# 0              18.75          0.00               -11.575              -0.1560
# 1              47.75          0.00                 1.390              -0.4446
# 2               0.00          0.52                -4.110               0.0104
# 3              72.50          0.00                -6.090              -0.5076
# 4               0.00          0.00                 4.475               0.1210
#
#    avgReceivedMins  avgOutCalls  avgInCalls  peakOffPeakRatio  \
# 0             0.00         0.00        0.00          0.000000
# 1           200.54        37.33       20.33          1.000000
# 2           120.13        59.00       19.00          0.435185
# 3           111.59        16.00       21.33          0.758830
# 4            45.73         7.00        2.00          0.554500
#
#    peakOffPeakRatioChangePct  avgDroppedCalls  lifeTime  \
# 0                 -15.071609             0.00        14
# 1                  -1.635469             9.67        11
# 2                  10.818753             3.00        31
# 3                   1.734207             8.00        16
# 4                  -4.839611             5.33        15
#
#    lastMonthCustomerCareCalls  numRetentionCalls  numRetentionOffersAccepted  \
# 0                        0.00                  0                           0
# 1                        3.67                  0                           0
# 2                        0.00                  0                           0
# 3                        0.00                  0                           0
# 4                        0.33                  0                           0
#
#    newFrequentNumbers   churn
# 0                   1   false
# 1                   0   false
# 2                   0   false
# 3                   0   false
# 4                   0   false

# %%
df.tail(5)
# Out:
#      customer   age     occupation  regionType marriageStatus  children  \
# 995   1029542    50   professional                        yes      true
# 996   1093453     0                                   unknown     false
# 997   1000481    50                   suburban            yes     false
# 998   1005803    46                       town            yes      true
# 999   1007686    54                   suburban             no     false
#
#       income  numHandsets  handsetAge smartPhone  currentHandsetPrice  \
# 995        9            6         160       true               129.99
# 996        0            1         285       true                 0.00
# 997        6            5         341       true                 9.99
# 998        7            2         413       true                29.99
# 999        6            1        1037       true                 0.00
#
#      creditRating homeOwner  creditCard  avgBill  avgMins  avgrecurringCharge  \
# 995             C     false        true    66.50  1339.75               54.99
# 996             C      true       false   139.48  1759.25               34.95
# 997             D     false        true    93.58  1804.00               75.00
# 998             A     false        true    25.19    32.50               24.99
# 999             C     false        true   101.33     3.25              108.74
#
#      avgOverBundleMins  avgRoamCalls  callMinutesChangePct  \
# 995              31.00          1.46                -1.075
# 996             244.00          0.00                -9.025
# 997              25.75          0.00                 4.100
# 998               0.00          0.20                 0.170
# 999               0.25          0.00                -0.065
#
#      billAmountChangePct  avgReceivedMins  avgOutCalls  avgInCalls  \
# 995              -0.0558           221.45        81.33       17.00
# 996              -0.9624           759.85       176.00       54.00
# 997               0.2606           600.84        54.33        1.33
# 998               0.0118             4.31         0.67        0.00
# 999              -2.0266             0.00         0.00        0.00
#
#      peakOffPeakRatio  peakOffPeakRatioChangePct  avgDroppedCalls  lifeTime  \
# 995          1.766497                  -2.947442            38.00        19
# 996          0.760969                   1.849624            28.33        10
# 997          7.469697                  -8.148106            18.00        49
# 998          4.405405                  -0.385591             0.00        34
# 999          0.000000                   2.329299             0.33        35
#
#      lastMonthCustomerCareCalls  numRetentionCalls  \
# 995                        1.33                  0
# 996                       19.00                  0
# 997                        0.00                  0
# 998                        0.00                  0
# 999                        0.00                  0
#
#      numRetentionOffersAccepted  newFrequentNumbers   churn
# 995                           0                   3    true
# 996                           0                   0   false
# 997                           0                   0   false
# 998                           0                   0    true
# 999                           0                   0    true

# %%
df.dtypes
# Out:
# customer                        int64
#  age                            int64
#  occupation                    object
#  regionType                    object
# marriageStatus                 object
#  children                      object
#  income                         int64
# numHandsets                     int64
# handsetAge                      int64
# smartPhone                     object
# currentHandsetPrice           float64
#  creditRating                  object
# homeOwner                      object
#  creditCard                    object
# avgBill                       float64
# avgMins                       float64
# avgrecurringCharge            float64
# avgOverBundleMins             float64
# avgRoamCalls                  float64
# callMinutesChangePct          float64
# billAmountChangePct           float64
# avgReceivedMins               float64
# avgOutCalls                   float64
# avgInCalls                    float64
# peakOffPeakRatio              float64
# peakOffPeakRatioChangePct     float64
# avgDroppedCalls               float64
# lifeTime                        int64
# lastMonthCustomerCareCalls    float64
# numRetentionCalls               int64
# numRetentionOffersAccepted      int64
# newFrequentNumbers              int64
# churn                          object
# dtype: object

# %%
#Convert the features to their appropriate data types

cat_columns = df[[' occupation', ' regionType', 
                  'marriageStatus', ' children', 'smartPhone', 
                 ' creditRating', 'homeOwner', ' creditCard', 'churn']]

for column in cat_columns:
    df[column] = df[column].astype('category')

# %%
cat_columns.describe().T

#Prepare a table with descriptive statistics for all the categorical features
# Out:
#                count unique       top freq
#  occupation     1000      8            753
#  regionType     1000      7            488
# marriageStatus  1000      3   unknown  406
#  children       1000      2     false  736
# smartPhone      1000      2      true  902
#  creditRating   1000      7         B  379
# homeOwner       1000      2     false  643
#  creditCard     1000      6      true  642
# churn           1000      2     false  508

# %%
df.describe().T

#Prepare a table with descriptive statistics for all the continuous features
# Out:
#                              count        mean         std        min  \
#  age                        1000.0   29.588000   21.993498   0.000000
#  income                     1000.0    4.185000    3.106191   0.000000
# numHandsets                 1000.0    1.912000    1.541633   1.000000
# handsetAge                  1000.0  373.095000  247.594897   1.000000
# currentHandsetPrice         1000.0   37.305380   56.432678   0.000000
# avgBill                     1000.0   60.726720   44.999344   0.000000
# avgMins                     1000.0  559.149490  561.181571   0.000000
# avgrecurringCharge          1000.0   46.624930   25.042044   0.000000
# avgOverBundleMins           1000.0   45.971250   97.425469   0.000000
# avgRoamCalls                1000.0    1.091230    6.046520   0.000000
# callMinutesChangePct        1000.0   -0.340117    5.700590 -30.950000
# billAmountChangePct         1000.0    0.003890    0.863759  -5.514800
# avgReceivedMins             1000.0  129.041040  192.612672   0.000000
# avgOutCalls                 1000.0   26.764660   35.889503   0.000000
# avgInCalls                  1000.0    8.698590   16.949535   0.000000
# peakOffPeakRatio            1000.0    2.295173    5.586722   0.000000
# peakOffPeakRatioChangePct   1000.0    0.099909    9.976655 -34.937987
# avgDroppedCalls             1000.0   10.903310   14.936677   0.000000
# lifeTime                    1000.0   18.686000    9.440685   6.000000
# lastMonthCustomerCareCalls  1000.0    1.723540    3.896642   0.000000
# numRetentionCalls           1000.0    0.049000    0.229459   0.000000
# numRetentionOffersAccepted  1000.0    0.017000    0.129336   0.000000
# newFrequentNumbers          1000.0    0.208000    0.670213   0.000000
#
#                                    25%         50%         75%         max
#  age                          0.000000   34.000000   46.500000    90.00000
#  income                       0.000000    5.000000    6.000000     9.00000
# numHandsets                   1.000000    1.000000    2.000000    21.00000
# handsetAge                  203.000000  330.000000  513.250000  1463.00000
# currentHandsetPrice           0.000000    0.000000   59.990000   299.99000
# avgBill                      34.107500   49.710000   74.165000   476.64000
# avgMins                     176.312500  379.375000  753.000000  4093.50000
# avgrecurringCharge           30.000000   44.990000   59.990000   299.99000
# avgOverBundleMins             0.000000    5.750000   48.375000  1099.25000
# avgRoamCalls                  0.000000    0.000000    0.290000   143.79000
# callMinutesChangePct         -2.033750   -0.152500    1.343750    37.95500
# billAmountChangePct          -0.160150   -0.010000    0.033400    10.19500
# avgReceivedMins              10.345000   58.180000  169.602500  1714.21000
# avgOutCalls                   3.670000   14.330000   35.415000   312.33000
# avgInCalls                    0.000000    2.165000    9.330000   204.33000
# peakOffPeakRatio              0.776299    1.423310    2.492122   160.00000
# peakOffPeakRatioChangePct    -6.323852    0.272918    6.393022    31.89289
# avgDroppedCalls               2.000000    6.000000   14.670000   124.33000
# lifeTime                     11.000000   17.000000   24.000000    58.00000
# lastMonthCustomerCareCalls    0.000000    0.000000    1.670000    49.33000
# numRetentionCalls             0.000000    0.000000    0.000000     2.00000
# numRetentionOffersAccepted    0.000000    0.000000    0.000000     1.00000
# newFrequentNumbers            0.000000    0.000000    0.000000     3.00000

# %%
#Drop duplicate rows and columns, if any

len(df['customer'].unique())
# Out:
# 1000

# %%
#Drop constant columns, if any

print("Feature, UniqueValues")
for column in df:
    print (column + "," + str(len(df[column].unique())))
# Out:
# Feature, UniqueValues
# customer,1000
#  age,36
#  occupation,8
#  regionType,7
# marriageStatus,3
#  children,2
#  income,10
# numHandsets,12
# handsetAge,573
# smartPhone,2
# currentHandsetPrice,11
#  creditRating,7
# homeOwner,2
#  creditCard,6
# avgBill,851
# avgMins,885
# avgrecurringCharge,264
# avgOverBundleMins,369
# avgRoamCalls,173
# callMinutesChangePct,781
# billAmountChangePct,738
# avgReceivedMins,867
# avgOutCalls,266
# avgInCalls,141
# peakOffPeakRatio,904
# peakOffPeakRatioChangePct,1000
# avgDroppedCalls,146
# lifeTime,49
# lastMonthCustomerCareCalls,53
# numRetentionCalls,3
# numRetentionOffersAccepted,2
# newFrequentNumbers,4
# churn,2

# %%
#Check for excessive null values

df.isnull().sum()
# Out:
# customer                      0
#  age                          0
#  occupation                   0
#  regionType                   0
# marriageStatus                0
#  children                     0
#  income                       0
# numHandsets                   0
# handsetAge                    0
# smartPhone                    0
# currentHandsetPrice           0
#  creditRating                 0
# homeOwner                     0
#  creditCard                   0
# avgBill                       0
# avgMins                       0
# avgrecurringCharge            0
# avgOverBundleMins             0
# avgRoamCalls                  0
# callMinutesChangePct          0
# billAmountChangePct           0
# avgReceivedMins               0
# avgOutCalls                   0
# avgInCalls                    0
# peakOffPeakRatio              0
# peakOffPeakRatioChangePct     0
# avgDroppedCalls               0
# lifeTime                      0
# lastMonthCustomerCareCalls    0
# numRetentionCalls             0
# numRetentionOffersAccepted    0
# newFrequentNumbers            0
# churn                         0
# dtype: int64

# %%
#Save your updated/cleaned data frame to a new csv file

df.to_csv('CleanChurn-17205709.csv', index=False)

# %%
df = pd.read_csv('CleanChurn-17205709.csv')
df.head(20)
# Out:
#     customer   age     occupation  regionType marriageStatus  children  \
# 0    1074015     0                                   unknown     false
# 1    1067357    70                   suburban             no     false
# 2    1014203    52        retired    suburban            yes      true
# 3    1061952     0                    unknown        unknown     false
# 4    1059557    26                                        no     false
# 5    1004312    34                   suburban            yes      true
# 6    1049232     0                                   unknown     false
# 7    1043401     0                   suburban        unknown     false
# 8    1082587    52                   suburban             no     false
# 9    1053535    58                                   unknown     false
# 10   1016984    34                                   unknown     false
# 11   1072328    34                                        no     false
# 12   1003939     0                                   unknown     false
# 13   1070194    52                                       yes      true
# 14   1096013    36   professional    suburban            yes      true
# 15   1012782    38                                        no     false
# 16   1076761    40                                       yes      true
# 17   1012684    26                   suburban             no     false
# 18   1006867    44                      rural             no     false
# 19   1041887    54   professional    suburban            yes     false
#
#      income  numHandsets  handsetAge smartPhone  currentHandsetPrice  \
# 0         0            1         403       true                 0.00
# 1         7            2         279       true                29.99
# 2         8            2           5      false                29.99
# 3         0            1         478       true                 0.00
# 4         3            1         430       true                 0.00
# 5         6            1        1137      false                 0.00
# 6         9            1         506       true                 0.00
# 7         0            2         222       true               149.99
# 8         2            1         264       true                 0.00
# 9         6            1         361       true                 0.00
# 10        7            1         776       true                 0.00
# 11        3            1         305       true                 0.00
# 12        0            3         690       true                29.99
# 13        8            3          76       true               149.99
# 14        7            2          89       true               149.99
# 15        1            3         851      false                29.99
# 16        4            1         284       true                 0.00
# 17        8            1         907      false                 0.00
# 18        6            1        1001       true                 0.00
# 19        8            1         530       true                 0.00
#
#     creditRating homeOwner  creditCard  avgBill  avgMins  avgrecurringCharge  \
# 0              G      true       false    42.79  1097.75               44.99
# 1              E     false        true    62.22   605.50               41.28
# 2              G     false        true    35.75   558.50               44.99
# 3              D      true       false    55.37   362.50               39.99
# 4              B     false           t    33.85   246.25               30.00
# 5              F     false        true    49.99   327.00               49.99
# 6              B     false        true   127.12   953.25               49.99
# 7              C      true       false    60.65   634.50               49.99
# 8              B     false        true    35.16    59.00               39.99
# 9              B     false        true    30.26   112.50               39.99
# 10             G     false       false    71.76   161.25               29.99
# 11             G      true        true    53.55   524.25               50.43
# 12             A      true       false    55.68  1805.25               39.99
# 13             D     false        true    63.01   444.25               69.99
# 14             C     false        true    10.50   144.25               10.00
# 15             C      true        true   137.24  1123.50               86.26
# 16             B     false        true    13.02   230.25               10.00
# 17             A     false        true    36.40    31.75               29.99
# 18             C     false        true    55.54   129.50               32.49
# 19             E     false        true    47.79   146.75               36.99
#
#     avgOverBundleMins  avgRoamCalls  callMinutesChangePct  \
# 0               18.75          0.00               -11.575
# 1               47.75          0.00                 1.390
# 2                0.00          0.52                -4.110
# 3               72.50          0.00                -6.090
# 4                0.00          0.00                 4.475
# 5                0.00          0.00                -0.620
# 6              213.50          0.00                 7.775
# 7                0.00          0.00                -5.330
# 8                0.00          5.17                 0.400
# 9                0.00          0.00                 0.550
# 10              61.75         20.15                 4.575
# 11              36.75          0.00                -0.165
# 12              40.50          0.00               -18.905
# 13               0.00          0.81                 3.995
# 14               0.00          0.00                 1.815
# 15             183.00          0.00                -6.050
# 16               0.00          0.29                -0.285
# 17               0.00          5.73                -0.535
# 18               0.00         22.80                 3.750
# 19              52.00          0.00                 2.025
#
#     billAmountChangePct  avgReceivedMins  avgOutCalls  avgInCalls  \
# 0               -0.1560             0.00         0.00        0.00
# 1               -0.4446           200.54        37.33       20.33
# 2                0.0104           120.13        59.00       19.00
# 3               -0.5076           111.59        16.00       21.33
# 4                0.1210            45.73         7.00        2.00
# 5                0.0000            35.27        30.67        1.33
# 6                0.0734           229.70        89.67       33.00
# 7               -0.1022           106.80        35.67       15.67
# 8               -0.1034             0.00         0.33        0.00
# 9               -0.0054             0.49         1.00        0.00
# 10               0.8938            29.53         6.33        0.00
# 11               0.2448           378.73         8.00        7.33
# 12               0.5418           487.07        43.33        3.67
# 13              -0.0448            63.36        20.33        1.33
# 14              -0.0100             0.53         0.33        0.00
# 15              -0.5986           255.24        75.67       17.00
# 16              -0.0008            36.68        32.00        4.00
# 17              -0.1282             0.00         1.00        0.00
# 18               1.3416             0.22         1.67        0.00
# 19               1.1080             9.44         9.67        3.00
#
#     peakOffPeakRatio  peakOffPeakRatioChangePct  avgDroppedCalls  lifeTime  \
# 0           0.000000                 -15.071609             0.00        14
# 1           1.000000                  -1.635469             9.67        11
# 2           0.435185                  10.818753             3.00        31
# 3           0.758830                   1.734207             8.00        16
# 4           0.554500                  -4.839611             5.33        15
# 5           2.067042                  15.037492             4.00        38
# 6           2.818608                  16.275749            15.67        17
# 7           0.750707                  11.255496            18.00        17
# 8           0.570815                 -13.725407             0.33         9
# 9           4.055292                  -9.824126             1.33        12
# 10          2.600900                   4.675006             1.67        26
# 11          0.637383                  19.157725             4.33        10
# 12          1.002712                   5.268500            11.67        41
# 13          2.470296                  -2.409844            10.33        10
# 14          1.175544                   9.314427             5.33         8
# 15          7.011251                   7.363264            18.00        32
# 16          1.845378                  -6.349502             5.67         9
# 17          2.759398                  -9.242507             0.67        30
# 18          5.925054                   1.197269             2.00        33
# 19          0.700000                 -11.554908             1.00        17
#
#     lastMonthCustomerCareCalls  numRetentionCalls  numRetentionOffersAccepted  \
# 0                         0.00                  0                           0
# 1                         3.67                  0                           0
# 2                         0.00                  0                           0
# 3                         0.00                  0                           0
# 4                         0.33                  0                           0
# 5                         0.00                  0                           0
# 6                         0.00                  0                           0
# 7                         0.33                  0                           0
# 8                         0.00                  0                           0
# 9                         0.67                  0                           0
# 10                        0.33                  0                           0
# 11                        4.00                  0                           0
# 12                        7.00                  0                           0
# 13                        2.67                  0                           0
# 14                        0.00                  0                           0
# 15                        0.67                  0                           0
# 16                        0.00                  0                           0
# 17                        0.00                  0                           0
# 18                        0.00                  0                           0
# 19                        0.00                  0                           0
#
#     newFrequentNumbers   churn
# 0                    1   false
# 1                    0   false
# 2                    0   false
# 3                    0   false
# 4                    0   false
# 5                    0    true
# 6                    0   false
# 7                    0   false
# 8                    0   false
# 9                    0   false
# 10                   0    true
# 11                   0   false
# 12                   0   false
# 13                   0    true
# 14                   0   false
# 15                   0   false
# 16                   0   false
# 17                   0    true
# 18                   0    true
# 19                   0    true

# %%
# - Plot bar plots for all the categorical features

pp = PdfPages('cat_bar_charts.pdf')

for column in cat_columns:
    f = df[column].value_counts().plot(kind='bar', title=column, figsize=(12,5))
    pp.savefig(f.get_figure())
    plt.show()
    
pp.close()

# %%
# - Plot histograms for all the continuous features.

numeric_columns = df.select_dtypes(['int64','float64']).columns
df[numeric_columns].hist(figsize=(30,30))

plt.savefig('con_histograms.pdf')

# %%
# - Plot box plots for all the continuous features.

pp = PdfPages('con_box_plots.pdf')

for column in numeric_columns:
    f = df[column].plot(kind='box', figsize=(10,10))
    pp.savefig(f.get_figure())
    plt.show()
pp.close()
